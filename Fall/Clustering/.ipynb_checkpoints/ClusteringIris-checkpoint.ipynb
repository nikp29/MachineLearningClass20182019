# %% [markdown]
# # Clustering
#
# See our notes on [unsupervised learning](https://jennselby.github.io/MachineLearningCourseNotes/#unsupervised-learning), [K-means](https://jennselby.github.io/MachineLearningCourseNotes/#k-means-clustering), [DBSCAN](https://jennselby.github.io/MachineLearningCourseNotes/#dbscan-clustering), and [clustering validation](https://jennselby.github.io/MachineLearningCourseNotes/#clustering-validation).
#
# For documentation of various clustering methods in scikit-learn, see http://scikit-learn.org/stable/modules/clustering.html
#
# The code was based on the example at http://scikit-learn.org/stable/auto_examples/cluster/plot_cluster_iris.html
# which has the following comments:
#
# Code source: Gaël Varoquaux<br/>
# Modified for documentation by Jaques Grobler<br/>
# License: BSD 3 clause

# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn import datasets

import pandas as pd

# %%
# We can only plot 3 of the 4 iris features, since we only see in 3D.
# These are the ones the example code picked
X_FEATURE = 'petal width (cm)' 
Y_FEATURE = 'sepal length (cm)' 
Z_FEATURE = 'petal length (cm)'

FIGURES_PER_ROW = 3 
MAX_CLUSTERS = 6

# %%
def add_plot(figure, subplot_num, subplot_name, data, labels):
    '''Create a new subplot in the figure.'''

    # create a new subplot
    axis = figure.add_subplot(FIGURES_PER_ROW, MAX_CLUSTERS / FIGURES_PER_ROW, subplot_num, projection='3d',
                              elev=48, azim=134)

    # Plot three of the four features on the graph, and set the color according to the labels
    axis.scatter(data[X_FEATURE], data[Y_FEATURE], data[Z_FEATURE], c=labels)

    # get rid of the tick numbers. Otherwise, they all overlap and it looks horrible
    for axis_obj in [axis.w_xaxis, axis.w_yaxis, axis.w_zaxis]:
        axis_obj.set_ticklabels([])

    # label the subplot
    axis.title.set_text(subplot_name)

# %% [markdown]
# ## Iris Dataset
#
# Before you go on, if you haven't used the iris dataset in a previous assignment, make sure you understand it. Modify the cell below to examine different parts of the dataset that are contained in the iris dictionary object.
#
# What are the features? What are we trying to classify?

# %%
iris = datasets.load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
iris_df = pd.DataFrame(iris.data)
iris_df.columns = iris.feature_names
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ## Visualization
#
# This is the correct labeling, based on the targets.

# %%
# start a new figure to hold all of the subplots
figure = matplotlib.pyplot.figure(figsize=(4*FIGURES_PER_ROW, MAX_CLUSTERS))

# Plot the ground truth
add_plot(figure, 1, "Ground Truth", iris_df, iris.target)

# %% [markdown]
# ## Training and Visualization
#
# Now let's see how k-means clusters the iris dataset, with various different numbers of clusters

# %%
figure = matplotlib.pyplot.figure(figsize=(4*FIGURES_PER_ROW, MAX_CLUSTERS))
# Plot the ground truth
add_plot(figure, 1, "Ground Truth", iris_df, iris.target)

for num_clusters in range(2, MAX_CLUSTERS + 1):
    # train the model
    model = KMeans(n_clusters=num_clusters)
    model.fit(iris_df)
    # get the predictions of which cluster each input is in
    labels = model.labels_

    add_plot(figure, num_clusters, '{} Clusters'.format(num_clusters), iris_df, labels.astype(numpy.float))

# %% [markdown]
# # Exercise
#
# 1. Add [validation](https://jennselby.github.io/MachineLearningCourseNotes/#clustering-validation) to measure how good the clustering is, with different numbers of clusters.
# 878041  2003-01-06 00:31:00          OTHER OFFENSES
# 878042  2003-01-06 00:20:00                 ASSAULT
# 878043  2003-01-06 00:20:00          OTHER OFFENSES
# 878044  2003-01-06 00:15:00                 ROBBERY
# 878045  2003-01-06 00:01:00           LARCENY/THEFT
# 878046  2003-01-06 00:01:00           LARCENY/THEFT
# 878047  2003-01-06 00:01:00               VANDALISM
# 878048  2003-01-06 00:01:00  FORGERY/COUNTERFEITING
#
#                                          Descript  DayOfWeek  PdDistrict  \
# 0                                  WARRANT ARREST  Wednesday    NORTHERN
# 1                        TRAFFIC VIOLATION ARREST  Wednesday    NORTHERN
# 2                        TRAFFIC VIOLATION ARREST  Wednesday    NORTHERN
# 3                    GRAND THEFT FROM LOCKED AUTO  Wednesday    NORTHERN
# 4                    GRAND THEFT FROM LOCKED AUTO  Wednesday        PARK
# 5                  GRAND THEFT FROM UNLOCKED AUTO  Wednesday   INGLESIDE
# 6                               STOLEN AUTOMOBILE  Wednesday   INGLESIDE
# 7                               STOLEN AUTOMOBILE  Wednesday     BAYVIEW
# 8                    GRAND THEFT FROM LOCKED AUTO  Wednesday    RICHMOND
# 9                    GRAND THEFT FROM LOCKED AUTO  Wednesday     CENTRAL
# 10                   PETTY THEFT FROM LOCKED AUTO  Wednesday     CENTRAL
# 11                    MISCELLANEOUS INVESTIGATION  Wednesday     TARAVAL
# 12      MALICIOUS MISCHIEF, VANDALISM OF VEHICLES  Wednesday  TENDERLOIN
# 13                   GRAND THEFT FROM LOCKED AUTO  Wednesday    NORTHERN
# 14                                 FOUND PROPERTY  Wednesday     BAYVIEW
# 15                                 FOUND PROPERTY  Wednesday     BAYVIEW
# 16                    ROBBERY, ARMED WITH A KNIFE  Wednesday  TENDERLOIN
# 17           AGGRAVATED ASSAULT WITH BODILY FORCE  Wednesday   INGLESIDE
# 18                              TRAFFIC VIOLATION  Wednesday     BAYVIEW
# 19                                 FOUND PROPERTY  Wednesday  TENDERLOIN
# 20                   GRAND THEFT FROM LOCKED AUTO  Wednesday   INGLESIDE
# 21                          ROBBERY, BODILY FORCE  Wednesday   INGLESIDE
# 22                                 WARRANT ARREST  Wednesday  TENDERLOIN
# 23       STAY AWAY OR COURT ORDER, NON-DV RELATED  Wednesday  TENDERLOIN
# 24                   GRAND THEFT FROM LOCKED AUTO  Wednesday    NORTHERN
# 25                                  LOST PROPERTY  Wednesday  TENDERLOIN
# 26                   GRAND THEFT FROM LOCKED AUTO  Wednesday    NORTHERN
# 27                   GRAND THEFT FROM LOCKED AUTO  Wednesday   INGLESIDE
# 28            ATTEMPTED THEFT FROM LOCKED VEHICLE  Wednesday     TARAVAL
# 29                    MISCELLANEOUS INVESTIGATION  Wednesday     TARAVAL
# ...                                           ...        ...         ...
# 878019      DRIVERS LICENSE, SUSPENDED OR REVOKED     Monday    SOUTHERN
# 878020                          TRAFFIC VIOLATION     Monday    NORTHERN
# 878021                         MALICIOUS MISCHIEF     Monday    NORTHERN
# 878022      RECOVERED VEHICLE - STOLEN OUTSIDE SF     Monday     MISSION
# 878023                     GRAND THEFT PICKPOCKET     Monday  TENDERLOIN
# 878024         VIOLATION OF MUNICIPAL POLICE CODE     Monday        PARK
# 878025                          TRAFFIC VIOLATION     Monday     BAYVIEW
# 878026                             WARRANT ARREST     Monday     BAYVIEW
# 878027            ENROUTE TO OUTSIDE JURISDICTION     Monday    SOUTHERN
# 878028       AGGRAVATED ASSAULT WITH BODILY FORCE     Monday    SOUTHERN
# 878029                        PROBATION VIOLATION     Monday  TENDERLOIN
# 878030                FORCIBLE RAPE, BODILY FORCE     Monday  TENDERLOIN
# 878031                                    BATTERY     Monday     BAYVIEW
# 878032      DRIVERS LICENSE, SUSPENDED OR REVOKED     Monday    NORTHERN
# 878033              MALICIOUS MISCHIEF, VANDALISM     Monday    RICHMOND
# 878034                                TRESPASSING     Monday    RICHMOND
# 878035                                    BATTERY     Monday    NORTHERN
# 878036                    PETTY THEFT SHOPLIFTING     Monday    NORTHERN
# 878037              MALICIOUS MISCHIEF, VANDALISM     Monday    NORTHERN
# 878038            ENROUTE TO OUTSIDE JURISDICTION     Monday  TENDERLOIN
# 878039      DRIVERS LICENSE, SUSPENDED OR REVOKED     Monday    NORTHERN
# 878040                INFLICT INJURY ON COHABITEE     Monday     MISSION
# 878041      DRIVERS LICENSE, SUSPENDED OR REVOKED     Monday    RICHMOND
# 878042              ATTEMPTED HOMICIDE WITH A GUN     Monday     BAYVIEW
# 878043                           PAROLE VIOLATION     Monday     BAYVIEW
# 878044           ROBBERY ON THE STREET WITH A GUN     Monday     TARAVAL
# 878045               GRAND THEFT FROM LOCKED AUTO     Monday   INGLESIDE
# 878046               GRAND THEFT FROM LOCKED AUTO     Monday    SOUTHERN
# 878047  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES     Monday    SOUTHERN
# 878048                   CHECKS, FORGERY (FELONY)     Monday     BAYVIEW
#
#             Resolution                        Address           X          Y
# 0       ARREST, BOOKED             OAK ST / LAGUNA ST -122.425892  37.774599
# 1       ARREST, BOOKED             OAK ST / LAGUNA ST -122.425892  37.774599
# 2       ARREST, BOOKED      VANNESS AV / GREENWICH ST -122.424363  37.800414
# 3                 NONE       1500 Block of LOMBARD ST -122.426995  37.800873
# 4                 NONE      100 Block of BRODERICK ST -122.438738  37.771541
# 5                 NONE            0 Block of TEDDY AV -122.403252  37.713431
# 6                 NONE            AVALON AV / PERU AV -122.423327  37.725138
# 7                 NONE       KIRKWOOD AV / DONAHUE ST -122.371274  37.727564
# 8                 NONE           600 Block of 47TH AV -122.508194  37.776601
# 9                 NONE  JEFFERSON ST / LEAVENWORTH ST -122.419088  37.807802
# 10                NONE  JEFFERSON ST / LEAVENWORTH ST -122.419088  37.807802
# 11                NONE          0 Block of ESCOLTA WY -122.487983  37.737667
# 12                NONE             TURK ST / JONES ST -122.412414  37.783004
# 13                NONE         FILLMORE ST / GEARY BL -122.432915  37.784353
# 14                NONE       200 Block of WILLIAMS AV -122.397744  37.729935
# 15                NONE          0 Block of MENDELL ST -122.383692  37.743189
# 16                NONE             EDDY ST / JONES ST -122.412597  37.783932
# 17                NONE         GODEUS ST / MISSION ST -122.421682  37.742822
# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-dc11223ce65b> in <module>
# ----> 1 max(lat)
#
# NameError: name 'lat' is not defined

# %%
lat = newdata['Y'].values
lon = newdata['X'].values
# determine range to print based on min, max lat and lon of the data
margin = .1 # buffer to add to the range
lat_min = min(lat) - margin
lat_max = max(lat) + margin
lon_min = min(lon) - margin
lon_max = max(lon) + margin

# create map using BASEMAP
m = Basemap(llcrnrlon=lon_min,
            llcrnrlat=lat_min,
            urcrnrlon=lon_max,
            urcrnrlat=lat_max,
            lat_0=(lat_max - lat_min)/2,
            lon_0=(lon_max-lon_min)/2,
            projection='merc',
            resolution = 'h',
            area_thresh=10000.,
            )
m.drawcoastlines()
m.drawcountries()
m.drawstates()
m.drawmapboundary(fill_color='#46bcec')
m.fillcontinents(color = 'white',lake_color='#46bcec')


# convert lat and lon to map projection coordinates
lons, lats = m(lon, lat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-494247fbb3cf> in <module>
#      28 # convert lat and lon to map projection coordinates
#      29 lons, lats = m(lon, lat)
# ---> 30 m.scatter(label_data['lons'].values, label_data['lats'].values,1, marker ='o', color='r', zorder=5)
#      31 plt.show()
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in with_transform(self, x, y, *args, **kwargs)
#     565             # convert lat/lon coords to map projection coords.
#     566             x, y = self(x,y)
# --> 567         return plotfunc(self,x,y,*args,**kwargs)
#     568     return with_transform
#     569
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in scatter(self, *args, **kwargs)
#    3260             ret =  ax.scatter(*args, **kwargs)
#    3261         finally:
# -> 3262             self._restore_hold(ax)
#    3263         # reset current active image (only if pyplot is imported).
#    3264         if plt:
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute

# %%
m.plot?

# %%
m.scatter(x=label_data['lons'].values, y=label_data['lats'].values, marker='o', c='r', zorder=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-98199ea95f03> in <module>
# ----> 1 m.scatter(x=label_data['lons'].values, y=label_data['lats'].values, marker='o', c='r', zorder=5)
#       2 plt.show()
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in with_transform(self, x, y, *args, **kwargs)
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in scatter(self, *args, **kwargs)
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in _restore_hold(self, ax)
#
# AttributeError: can't set attribute

# %%
newdata['lons'], newdata['lats'] = lons, lats
scaler = preprocessing.StandardScaler()
newdata['lon_std'], newdata['lat_std'] = scaler.fit_transform(lons.reshape(-1, 1)), scaler.fit_transform(lats.reshape(-1, 1))
sampled_data = newdata.sample(frac=.01)
X = sampled_data[['lon_std','lat_std']].values

sampled_data
# Out:
#                       Dates                Category  \
# 40833   2014-10-28 20:35:00          OTHER OFFENSES
# 494292  2008-05-28 16:35:00          OTHER OFFENSES
# 579646  2007-03-05 14:48:00           LARCENY/THEFT
# 236838  2012-03-09 07:15:00          MISSING PERSON
#
#                                               Descript  DayOfWeek  PdDistrict  \
# 40833            DRIVERS LICENSE, SUSPENDED OR REVOKED    Tuesday     BAYVIEW
# 858665                      LOST PROPERTY, PETTY THEFT     Friday  TENDERLOIN
# 123863               BURGLARY OF STORE, UNLAWFUL ENTRY  Wednesday     CENTRAL
# 422622                BURGLARY OF FLAT, UNLAWFUL ENTRY     Friday     MISSION
# 203175                 ENROUTE TO OUTSIDE JURISDICTION    Tuesday     CENTRAL
# 380416                                  WARRANT ARREST     Sunday    SOUTHERN
# 188126                    GRAND THEFT FROM LOCKED AUTO    Tuesday    NORTHERN
# 241913       MALICIOUS MISCHIEF, VANDALISM OF VEHICLES     Friday     TARAVAL
# 8789                         LOST/STOLEN LICENSE PLATE  Wednesday        PARK
# 866848                   MALICIOUS MISCHIEF, VANDALISM   Saturday     BAYVIEW
# 686091                  PETTY THEFT FROM UNLOCKED AUTO  Wednesday    SOUTHERN
# 391242                                  WARRANT ARREST   Thursday    NORTHERN
# 129609                    AIDED CASE, MENTAL DISTURBED     Friday  TENDERLOIN
# 744544                      PEDDLING WITHOUT A LICENSE     Friday     BAYVIEW
# 688925           DRIVERS LICENSE, SUSPENDED OR REVOKED  Wednesday    RICHMOND
# 318622                         INVESTIGATIVE DETENTION   Saturday     TARAVAL
# 55181                                STOLEN AUTOMOBILE  Wednesday     MISSION
# 678444    UNDER INFLUENCE OF ALCOHOL IN A PUBLIC PLACE     Monday    NORTHERN
# 261691                  POSSESSION OF ALCOHOL BY MINOR     Monday     TARAVAL
# 519289                                         BATTERY     Monday     CENTRAL
# 421619                         POSSESSION OF MARIJUANA     Monday   INGLESIDE
# 325227                 ENROUTE TO OUTSIDE JURISDICTION    Tuesday    NORTHERN
# 262244                                   LOST PROPERTY     Sunday     CENTRAL
# 234156               POSSESSION OF MARIJUANA FOR SALES   Thursday    RICHMOND
# 240942                           HARASSING PHONE CALLS     Monday    SOUTHERN
# 185671                    GRAND THEFT FROM LOCKED AUTO     Monday     BAYVIEW
# 438857                    GRAND THEFT FROM LOCKED AUTO     Sunday    SOUTHERN
# 682879                                  WARRANT ARREST   Thursday  TENDERLOIN
# 387392                                         BATTERY     Sunday  TENDERLOIN
# 688774                     PETTY THEFT FROM A BUILDING  Wednesday     CENTRAL
# ...                                                ...        ...         ...
# 169040                     ROBBERY, ARMED WITH A KNIFE     Monday    NORTHERN
# 665151                        CHECKS, FORGERY (FELONY)   Saturday    NORTHERN
# 822386                                       LOITERING    Tuesday     MISSION
# 285210         LOITERING WHERE NARCOTICS ARE SOLD/USED   Saturday  TENDERLOIN
# 599682                    SALE OF CONTROLLED SUBSTANCE     Monday  TENDERLOIN
# 213034                         INVESTIGATIVE DETENTION   Thursday     MISSION
# 112477                 ENROUTE TO OUTSIDE JURISDICTION     Monday     MISSION
# 693315                                         BATTERY     Friday    SOUTHERN
# 73011                BURGLARY OF STORE, UNLAWFUL ENTRY    Tuesday     CENTRAL
# 869158           POSSESSION OF NARCOTICS PARAPHERNALIA     Monday    SOUTHERN
# 340130                    AIDED CASE, MENTAL DISTURBED     Friday        PARK
# 249763                           POSSESSION OF COCAINE   Saturday    SOUTHERN
# 215857                                    FOUND PERSON   Thursday  TENDERLOIN
# 128616                               STOLEN AUTOMOBILE     Sunday    SOUTHERN
# 787112                           ROBBERY, BODILY FORCE   Saturday     MISSION
# 498413                               STOLEN AUTOMOBILE   Saturday     CENTRAL
# 86523                        CIVIL SIDEWALKS, CITATION   Thursday        PARK
# 291631  FALSE PERSONATION TO RECEIVE MONEY OR PROPERTY  Wednesday     TARAVAL
# 61792                THEFT OF COMPUTERS OR CELL PHONES    Tuesday    SOUTHERN
# 763679                                           ARSON   Saturday        PARK
# 741241                         PETTY THEFT SHOPLIFTING   Saturday     TARAVAL
# 826636                        TRAFFIC VIOLATION ARREST   Saturday     MISSION
# 597202                    AIDED CASE, MENTAL DISTURBED     Monday    SOUTHERN
# 536795            MALICIOUS MISCHIEF, BREAKING WINDOWS    Tuesday     BAYVIEW
# 411928                         PETTY THEFT SHOPLIFTING    Tuesday    SOUTHERN
# 339499           LOITERING FOR PURPOSE OF PROSTITUTION     Sunday    NORTHERN
# 748236                                         BATTERY    Tuesday     CENTRAL
# 494292           DRIVERS LICENSE, SUSPENDED OR REVOKED  Wednesday     BAYVIEW
# 579646                         PETTY THEFT OF PROPERTY     Monday    SOUTHERN
# 236838                                    FOUND PERSON     Friday        PARK
#
#                               Resolution                              Address  \
# 40833                      ARREST, CITED                    PALOU AV / 3RD ST
# 858665                              NONE                  MARKET ST / HYDE ST
# 123863                    ARREST, BOOKED                500 Block of GEARY ST
# 422622                              NONE             700 Block of GUERRERO ST
# 203175                    ARREST, BOOKED                 BEACH ST / POWELL ST
# 380416                    ARREST, BOOKED               500 Block of FOLSOM ST
# 188126                              NONE                GOUGH ST / VALLEJO ST
# 241913                              NONE             500 Block of JOHNMUIR DR
# 8789                                NONE                  LYON ST / FULTON ST
# 866848                              NONE           100 Block of NORTHRIDGE RD
# 686091                              NONE                   6TH ST / MARKET ST
# 391242                    ARREST, BOOKED             OFARRELL ST / VANNESS AV
# 129609                 PSYCHOPATHIC CASE                400 Block of JONES ST
# 744544                     ARREST, CITED               100 Block of LOOMIS ST
# 688925                     ARREST, CITED                  FULTON ST / 14TH AV
# 318622                    ARREST, BOOKED                3200 Block of 20TH AV
# 55181                               NONE                2300 Block of 16TH ST
# 678444                    ARREST, BOOKED               LOMBARD ST / PIERCE ST
# 261691                              NONE             0 Block of WESTPORTAL AV
# 519289                              NONE                  200 Block of BAY ST
# 421619                    ARREST, BOOKED               SILVER AV / MISSION ST
# 325227                    ARREST, BOOKED               FRANKLIN ST / GEARY BL
# 262244                              NONE  THE EMBARCADERONORTH ST / POWELL ST
# 234156                    ARREST, BOOKED              400 Block of CLEMENT ST
# 240942                              NONE              100 Block of FREELON ST
# 185671                              NONE               20TH ST / TENNESSEE ST
# 438857                              NONE              1200 Block of BRYANT ST
# 682879                    ARREST, BOOKED             100 Block of OFARRELL ST
# 748236 -122.416614  37.786778  21908.504070  25140.740273  0.243196  0.817077
# 494292 -122.387458  37.749007  25150.515581  19827.649171  1.396316 -0.746214
# 579646 -122.413583  37.777044  22245.488724  23771.207368  0.363055  0.414114
# 236838 -122.443194  37.766543  18952.911957  22294.043945 -0.808050 -0.020518
#
# [8780 rows x 13 columns]

# %%
scanner = DBSCAN()
# plot points as red dots
sampled_data['labels'] = scanner.fit_predict(X)

# %%
max(lons)
min(lons)
# Out:
# 11119.487428467486

# %%
label_array = sampled_data['labels'].unique()
colors = 'bgrcmyk' #7 color values
markers = 'ov^8spP'


for i in range(len(label_array)):
    color_index = (i)%7
    marker_index = int((i-color_index)/7)
    print(colors[color_index], markers[marker_index])
    label_data = sampled_data[sampled_data['labels'] == label_array[i]]
    m.scatter(label_data['lons'].values, label_data['lats'].values,1, marker = markers[marker_index], color=colors[color_index], zorder=5)
# Out:
# b o
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-b4cd16bc7daf> in <module>
#      11     print(colors[color_index], markers[marker_index])
#      12     label_data = sampled_data[sampled_data['labels'] == label_array[i]]
# ---> 13     m.scatter(label_data['lons'].values, label_data['lats'].values,1, marker = markers[marker_index], color=colors[color_index], zorder=5)
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in with_transform(self, x, y, *args, **kwargs)
#     565             # convert lat/lon coords to map projection coords.
#     566             x, y = self(x,y)
# --> 567         return plotfunc(self,x,y,*args,**kwargs)
#     568     return with_transform
#     569
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in scatter(self, *args, **kwargs)
#    3260             ret =  ax.scatter(*args, **kwargs)
#    3261         finally:
# -> 3262             self._restore_hold(ax)
#    3263         # reset current active image (only if pyplot is imported).
#    3264         if plt:
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-cd6d7166de6d> in <module>
# ----> 1 m.scatter(lons, lats,1, zorder=5)
#       2 plt.show()
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in with_transform(self, x, y, *args, **kwargs)
#     565             # convert lat/lon coords to map projection coords.
#     566             x, y = self(x,y)
# --> 567         return plotfunc(self,x,y,*args,**kwargs)
#     568     return with_transform
#     569
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in scatter(self, *args, **kwargs)
#    3260             ret =  ax.scatter(*args, **kwargs)
#    3261         finally:
# -> 3262             self._restore_hold(ax)
#    3263         # reset current active image (only if pyplot is imported).
#    3264         if plt:
#
# ~/miniconda3/envs/jupyter/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute
